# %% [markdown]
# <a href="https://colab.research.google.com/github/mohanapriyaselvaraj2005-code/CodeVedx_Project1-/blob/main/Data_Analytics_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Dataset
data = {
    "Name": ["Arun", "Priya", "Kavin", "Meena", "Rahul"],
    "Age": [21, 22, 20, 23, 21],
    "Department": ["AI", "CSE", "AI", "ECE", "CSE"],
    "Marks": [85, 92, 78, 88, 95]
}

df = pd.DataFrame(data)

print("Student Dataset")
print(df)

print("\nSummary Statistics")
print(df.describe())

print("\nAverage Marks:", df["Marks"].mean())

# Bar Chart
plt.figure(figsize=(6,4))
plt.bar(df["Name"], df["Marks"])
plt.title("Student Marks")
plt.xlabel("Student Name")
plt.ylabel("Marks")
plt.grid(axis='y')
plt.show()

# Pie Chart
dept = df["Department"].value_counts()

plt.figure(figsize=(6,6))
plt.pie(dept, labels=dept.index, autopct="%1.1f%%")
plt.title("Department Distribution")
plt.show()
# Out:
# Student Dataset
#     Name  Age Department  Marks
# 0   Arun   21         AI     85
# 1  Priya   22        CSE     92
# 2  Kavin   20         AI     78
# 3  Meena   23        ECE     88
# 4  Rahul   21        CSE     95
#
# Summary Statistics
#              Age      Marks
# count   5.000000   5.000000
# mean   21.400000  87.600000
# std     1.140175   6.580274
# min    20.000000  78.000000
# 25%    21.000000  85.000000
# 50%    21.000000  88.000000
# 75%    22.000000  92.000000
# max    23.000000  95.000000
#
# Average Marks: 87.6
